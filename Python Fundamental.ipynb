# %% [markdown]
# IF STATEMENT

# %%
i = 10

# %%
if(i==10):
    print ("ini adalah angka 10")
# Out:
# ini adalah angka 10

# %%
i = 1000

# %%
if(i==1000):
    print("ini adalah angka 100")
# Out:
# ini adalah angka 100

# %% [markdown]
# IF ELSE

# %%
x = 34

# %%
if(x==35):
    print("ini adalah angka 34")
else: 
    print("bukan angka 34")
# Out:
# bukan angka 34

# %%
z = 1345

# %%
if(z==2324):
    print("ini adalah nilai 2324")
else:
    print("bukan angka 7454")
# Out:
# bukan angka 7454

# %%
y = 456

# %%
if(y==456):
    print("ini adalah nilai 456")
else: 
    print("bukan angka 7644")
# Out:
# ini adalah nilai 456

# %% [markdown]
# IF … ELIF … ELSE ….

# %%
v = 45

# %% [markdown]
# if(v==45):
#     print("ini adalah angka 45")
# elif(v>46):
#     print("lebih besar dari angka 46")
# else:
#     print("lebih kecil dari 45")

# %% [markdown]
# NESTED IF

# %% [markdown]
# Fungsi if sendiri bisa digunakan secara bertingkat atau dilakukan pengecekan lebih dari 1 statement di dalamnya
#
# if (i<7 && i <3)

# %%
i = 2

# %% [markdown]
# Praktek Operasi Matematika

# %% [markdown]
# Operasi modulus

# %%
c=4864
d=78

# %%
modulus=c%d
print("hasil modulus", modulus)
# Out:
# hasil modulus 28

# %%
b=2345
g=834

# %%
modulus=b%g
print("hasil modulus", modulus)
# Out:
# hasil modulus 677

# %%
angka=348394349

# %%
if(angka%2==0):
    print("angka termasuk bilangan genap")
else:
    print("angka termasuk bilangan ganjil")
# Out:
# angka termasuk bilangan ganjil

# %% [markdown]
# LOOPING
#
# While

# %%
j = 1

# %%
while j<6:
    print("ini adalah perulangan ke -",j)
j=j+1
