# %% [markdown]
# a = Insert cell above
# b = insert cell below
# double d = delete cell
# m = markdown
# y = code
# shift + enter = run

# %% [markdown]
# #MATERI NUMPY

# %%
import numpy as np

# %% [markdown]
# List

# %%
a = [1, 2, 3, 4]
b = [5, 6, 7, 8]

# %%
a_array = np.array(a)
b_array = np.array(b)

print(a_array + b_array)
print(a_array * b_array)
# Out:
# [ 6  8 10 12]
# [ 5 12 21 32]

# %% [markdown]
# CREATING NUMPY ARRAY

# %% [markdown]
# v.shape

# %% [markdown]
# m.size

# %% [markdown]
# m.dtype

# %% [markdown]
# Create Matrix Zeroes
